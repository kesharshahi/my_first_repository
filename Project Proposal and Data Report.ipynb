# %% [markdown]
# ##### Keshar Shahi (ks3984)

# %% [markdown]
# ### Project Proporsal & Data Report
# #### Data Bootcamp
# #### November 27, 2017

# %% [markdown]
# #### Project title:
# ## Do Prices of Airbnb Stays reflect the living cost of a city?

# %% [markdown]
# ### Background
#
# Founded in 2008, Airnb now has more than 150 million users. The online marketplace and hospitality service spans across 65000 cities in 191 countries. This service has now hosts more than half million guests away from their home. The  [projected](https://expandedramblings.com/index.php/airbnb-statistics/) revenue for the company is more than $2.8 Billion in 2017. Disrupting the hotel industry world-wide, Airbnb has now change the way people travel. As there are more than 4 million listings around the globe, it certainly has become more like an easy alternative to a hotel stay.
#
# But what does these Airbnb stays’ price reflects? As many of these listings are part of people’s own house or apartment, the pricing is certainly derived from a different calculation than a hotel’s room price.
#
# In this project, I would like to see the prices of these listing in different cities around the world and compare them with the income level of those host cities.
#
# Can a person with an average income of a particular city afford an Airbnb stay in the same city? I would like to find relation between income levels of a city and Airbnb stays.

# %% [markdown]
# ### Data Sources
#
# For Airbnb data, I am using [Inside Airbnb]( http://insideairbnb.com/get-the-data.html). This source provides me with the data on every listing from the 45 different cities around the world.
# For city wise income data, I am using Organization for Economic Co-operation and Development’s [data portal]( http://stats.oecd.org/index.aspx?queryid=51329). Since not all 34 cities are part of OECD, I will have to extract only the required 35 cities for my analysis.

# %% [markdown]
# ### Potential Challenges
#
# Since I will be selecting only cities part of OECD, I am face selection bias in my sample. The selection might  not necessarily focus the real picture for the rest of the world. For example, I will not be able to say anthing about a popular city from a developing country.
# Moreover, there will be some outliers within my data sets. Those outliers can be extrem high or low prices, or the type of property. The price between a whole house versus a shared room will have a huge different. In orde to address these problems, I will be cutting extreme outliers from my data. Also, I will do multiple data analysis for the property type. The analysis I am thinking is of doing one for a 'entire home/apartment' and another for a private room.

# %% [markdown]
# ### Data Report
# I have accessed to the necessary datasets. For this proposal, I am using downloaded data from my  local drive. I will be using online datasets for the final report.
# The brief overview of data I am using is as follow:

# %%
import pandas as pd                    # data package
import matplotlib.pyplot as plt        # graphics module  
import datetime as dt                  # date and time module
import numpy as np                     # foundation for pandas

# %%
#path = '/Users/kesharshahi/Desktop/Data_Bootcamp/cities.csv'

oecd = pd.read_csv('/Users/kesharshahi/Desktop/Data_Bootcamp/oecd.csv')
air = pd.read_csv('/Users/kesharshahi/Desktop/Data_Bootcamp/amsterdam.csv') 
#I have csv for each cities as of now. I will merge all of them after I get my desired analysis for each city.

# %%
oecd.head()
# Out:
#   METRO_ID Metropolitan areas        VAR  \
# 0    AT001             Vienna        GDP
# 1    AT001             Vienna  GDP_SHARE
# 2    AT001             Vienna     GDP_PC
# 3    BE001           Brussels        GDP
# 4    BE001           Brussels  GDP_SHARE
#
#                                            Variables  TIME  Year Unit Code  \
# 0                                 GDP (millions US$)  2012  2012       USD
# 1  GDP of the metropolitan area as a share of nat...  2012  2012        PC
# 2                               GDP per capita (US$)  2012  2012       USD
# 3                                 GDP (millions US$)  2012  2012       USD
# 4  GDP of the metropolitan area as a share of nat...  2012  2012        PC
#
#          Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0   US Dollar               6  Millions                 2010.0
# 1  Percentage               0     Units                    NaN
# 2   US Dollar               0     Units                 2010.0
# ...

# %%
air.head()
# Out:
#          id                                               name   host_id  \
# 0  14831696  Luxurious & spacecious apartm. with garden 6sleep   5476119
# 1   3951251                    Great app near Jordaan +2 bikes   3526186
# 2  16590973                  Trendy apartment, near Vondelpark  12749039
# 3   9283701                 Modern apartment in Amsterdam West  46755996
# 4   6458721                 (Balcony with) canal view Oud-West  15317293
#
#         host_name  neighbourhood_group           neighbourhood   latitude  \
# 0          Arthur                  NaN  De Baarsjes - Oud-West  52.361173
# 1  Dirk & Arjenne                  NaN  De Baarsjes - Oud-West  52.370237
# 2          Sheryl                  NaN  De Baarsjes - Oud-West  52.362016
# 3        Christie                  NaN  De Baarsjes - Oud-West  52.365826
# 4           Erwin                  NaN  De Baarsjes - Oud-West  52.364179
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
oecd.describe()
# Out:
#          TIME    Year  PowerCode Code  Reference Period Code  \
# count   132.0   132.0      132.000000                   99.0
# mean   2012.0  2012.0        1.500000                 2010.0
# std       0.0     0.0        2.607974                    0.0
# min    2012.0  2012.0        0.000000                 2010.0
# 25%    2012.0  2012.0        0.000000                 2010.0
# 50%    2012.0  2012.0        0.000000                 2010.0
# 75%    2012.0  2012.0        1.500000                 2010.0
# max    2012.0  2012.0        6.000000                 2010.0
#
#        Reference Period         Value  Flag Codes  Flags
# count              99.0  1.320000e+02         0.0    0.0
# mean             2010.0  9.424824e+04         NaN    NaN
# std                 0.0  1.437515e+05         NaN    NaN
# min              2010.0  5.000000e-01         NaN    NaN
# 25%              2010.0  1.543335e+04         NaN    NaN
# 50%              2010.0  6.518390e+04         NaN    NaN
# ...

# %%
air.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.518100e+04  1.518100e+04                  0.0  15181.000000
# mean   9.733629e+06  3.106406e+07                  NaN     52.365353
# std    5.366683e+06  3.166049e+07                  NaN      0.015738
# min    2.818000e+03  3.159000e+03                  NaN     52.290308
# 25%    5.117824e+06  6.701188e+06                  NaN     52.355616
# 50%    1.008104e+07  1.807277e+07                  NaN     52.365028
# 75%    1.431790e+07  4.714416e+07                  NaN     52.374829
# max    1.801401e+07  1.238477e+08                  NaN     52.426224
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  15181.000000  15181.000000    15181.000000       15181.000000
# mean       4.889025    134.799223        2.882551          17.785456
# std        0.034901     85.751273        7.215722          34.747999
# ...

# %%
air.shape
# Out:
# (15181, 16)

# %%
oecd.shape 
#since each cities data are in multiple lines, the number of rows are threefold than actual numbers
#of cities in my analysis.
# Out:
# (132, 15)
